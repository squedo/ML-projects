# %% [markdown]
# # Cells samples cancer - Supervised learning - classification
#
# The example is based on a dataset that is publicly available from the UCI Machine Learning Repository (Asuncion and Newman, 2007)[http://mlearn.ics.uci.edu/MLRepository.html].
#
# |Field name|Description|
# |--- |--- |
# |ID|Clump thickness|
# |Clump|Clump thickness|
# |UnifSize|Uniformity of cell size|
# |UnifShape|Uniformity of cell shape|
# |MargAdh|Marginal adhesion|
# |SingEpiSize|Single epithelial cell size|
# |BareNuc|Bare nuclei|
# |BlandChrom|Bland chromatin|
# |NormNucl|Normal nucleoli|
# |Mit|Mitoses|
# |Class|Benign or malignant|
#
# We want to run a model that will differenciate between benign and malignant cells.
#
# We will use neural network to obtain the model that gives us a Mean accuracy based on 10 random partitions of the total dataset = 0.941

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cell_samples.csv')

# %%
df.head()
# Out:
#         ID  Clump  UnifSize  UnifShape  MargAdh  SingEpiSize BareNuc  \
# 0  1000025      5         1          1        1            2       1
# 1  1002945      5         4          4        5            7      10
# 2  1015425      3         1          1        1            2       2
# 3  1016277      6         8          8        1            3       4
# 4  1017023      4         1          1        3            2       1
#
#    BlandChrom  NormNucl  Mit  Class
# 0           3         1    1      2
# 1           3         2    1      2
# 2           3         1    1      2
# 3           3         7    1      2
# 4           3         1    1      2

# %%
df.shape
# Out:
# (699, 11)

# %%
df.isna().sum()
# Out:
# ID             0
# Clump          0
# UnifSize       0
# UnifShape      0
# MargAdh        0
# SingEpiSize    0
# BareNuc        0
# BlandChrom     0
# NormNucl       0
# Mit            0
# Class          0
# dtype: int64

# %%
df.drop(columns = 'ID', inplace = True)

# %%
df.head()
# Out:
#    Clump  UnifSize  UnifShape  MargAdh  SingEpiSize BareNuc  BlandChrom  \
# 0      5         1          1        1            2       1           3
# 1      5         4          4        5            7      10           3
# 2      3         1          1        1            2       2           3
# 3      6         8          8        1            3       4           3
# 4      4         1          1        3            2       1           3
#
#    NormNucl  Mit  Class
# 0         1    1      2
# 1         2    1      2
# 2         1    1      2
# 3         7    1      2
# 4         1    1      2

# %%
df['Class'].unique()
# Out:
# array([2, 4], dtype=int64)

# %%
df['Class'].replace({2:0, 4:1}, inplace = True)

# %%
df['Class'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.head()
# Out:
#    Clump  UnifSize  UnifShape  MargAdh  SingEpiSize BareNuc  BlandChrom  \
# 0      5         1          1        1            2       1           3
# 1      5         4          4        5            7      10           3
# 2      3         1          1        1            2       2           3
# 3      6         8          8        1            3       4           3
# 4      4         1          1        3            2       1           3
#
#    NormNucl  Mit  Class
# 0         1    1      0
# 1         2    1      0
# 2         1    1      0
# 3         7    1      0
# 4         1    1      0

# %%
# The dataset is kind of imabalanced for every 2 benign cell we have 1 malignant cell info.
# That said we can work with this imbalance without having to applies any strategy to correct it.
df.groupby(['Class']).size()
# Out:
# Class
# 0    458
# 1    241
# dtype: int64

# %%
# We have a variable that is categorical BareNuc
df.dtypes
# Out:
# Clump           int64
# UnifSize        int64
# UnifShape       int64
# MargAdh         int64
# SingEpiSize     int64
# BareNuc        object
# BlandChrom      int64
# NormNucl        int64
# Mit             int64
# Class           int64
# dtype: object

# %%
# Transforming Categorical features to Numerical

for col_name in df.columns:
    if (df[col_name].dtype == 'object'):
        df[col_name]= df[col_name].astype('category')
        df[col_name] = df[col_name].cat.codes
        
df.head()
# Out:
#    Clump  UnifSize  UnifShape  MargAdh  SingEpiSize  BareNuc  BlandChrom  \
# 0      5         1          1        1            2        0           3
# 1      5         4          4        5            7        1           3
# 2      3         1          1        1            2        2           3
# 3      6         8          8        1            3        4           3
# 4      4         1          1        3            2        0           3
#
#    NormNucl  Mit  Class
# 0         1    1      0
# 1         2    1      0
# 2         1    1      0
# 3         7    1      0
# 4         1    1      0

# %%
# We drop highly correlated features
# Create correlation matrix
corr_matrix = df.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find features with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# Drop features 
df.drop(to_drop, axis=1, inplace=True)

# %%
df.head()
# Out:
#    Clump  UnifSize  UnifShape  MargAdh  SingEpiSize  BareNuc  BlandChrom  \
# 0      5         1          1        1            2        0           3
# 1      5         4          4        5            7        1           3
# 2      3         1          1        1            2        2           3
# 3      6         8          8        1            3        4           3
# 4      4         1          1        3            2        0           3
#
#    NormNucl  Mit  Class
# 0         1    1      0
# 1         2    1      0
# 2         1    1      0
# 3         7    1      0
# 4         1    1      0

# %%
# Now we want to select main features correlated with dependent variable Class

# Correlation with output variable
corr_matrix = df.corr().abs()
corr_matrix_target = abs(corr_matrix["Class"])

# Selecting highly correlated features
relevant_features = corr_matrix_target[corr_matrix_target > 0.5]
relevant_features
# Out:
# Clump          0.716001
# UnifSize       0.817904
# UnifShape      0.818934
# MargAdh        0.696800
# SingEpiSize    0.682785
# BlandChrom     0.756616
# NormNucl       0.712244
# Class          1.000000
# Name: Class, dtype: float64

# %%
# The variable BareNuc is discard for modeling as has a lower correlation to class than 0.5
df.drop(columns = 'BareNuc', inplace = True)

# %%
# We shouldn't need to Normalize the values since already of same order of magnitud
from sklearn.model_selection import train_test_split
#from sklearn.preprocessing import StandardScaler

val = df.values

X = val[:,0:val.shape[1]-1]
y = val[:,val.shape[1]-1]

# %%
# We load libraries, methods and functions to run the model as a neural network using Keras
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# We define our Neural network for classification problem:
def NeuralNetwork_classification_model():
    
    # Create model: x3 hidden layers and initializing with Initial layers with as many nodes as parameters we are considering in X_train or X_test
    model = Sequential()
    model.add(Dense(50, activation='relu', input_shape=(X_train.shape[1],)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    # Final layer would contain 2 nodes because we have a classification problem with 2 possible classes (survided or not)
    model.add(Dense(2, activation='softmax'))
    
    # compile model
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# We will run the model on 10 random splits of the dataset to get a solid value of accuracy:
acc = []

for i in range(0,10):
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, shuffle = True)
    model = NeuralNetwork_classification_model()
    model.fit(X_train, y_train, epochs=30, verbose=2)
    scores = model.evaluate(X_test, y_test, verbose=0)
    acc.append(scores[1])

accuracy = np.mean(acc)
print('Mean accuracy based on 10 random partitions of the total dataset = ', accuracy)
# Out:
# Train on 489 samples
# Epoch 1/30
# 489/489 - 0s - loss: 0.6732 - accuracy: 0.5378
# Epoch 2/30
# 489/489 - 0s - loss: 0.4813 - accuracy: 0.8384
# Epoch 3/30
# 489/489 - 0s - loss: 0.4010 - accuracy: 0.8609
# Epoch 4/30
# 489/489 - 0s - loss: 0.3517 - accuracy: 0.8732
# Epoch 5/30
# 489/489 - 0s - loss: 0.3040 - accuracy: 0.9121
# Epoch 6/30
# 489/489 - 0s - loss: 0.2709 - accuracy: 0.9202
# Epoch 7/30
# 489/489 - 0s - loss: 0.2349 - accuracy: 0.9305
# Epoch 8/30
# 489/489 - 0s - loss: 0.2147 - accuracy: 0.9468
# Epoch 9/30
# 489/489 - 0s - loss: 0.1892 - accuracy: 0.9509
# Epoch 10/30
# 489/489 - 0s - loss: 0.1649 - accuracy: 0.9550
# Epoch 11/30
# 489/489 - 0s - loss: 0.1533 - accuracy: 0.9489
# Epoch 12/30
# 489/489 - 0s - loss: 0.1293 - accuracy: 0.9673
# Epoch 13/30
# 489/489 - 0s - loss: 0.1179 - accuracy: 0.9693
# Epoch 14/30
# 489/489 - 0s - loss: 0.1128 - accuracy: 0.9734
# Epoch 15/30
# 489/489 - 0s - loss: 0.1052 - accuracy: 0.9673
# Epoch 16/30
# 489/489 - 0s - loss: 0.0891 - accuracy: 0.9714
# Epoch 17/30
# 489/489 - 0s - loss: 0.0838 - accuracy: 0.9775
# Epoch 18/30
# 489/489 - 0s - loss: 0.0752 - accuracy: 0.9816
# Epoch 19/30
# 489/489 - 0s - loss: 0.0842 - accuracy: 0.9693
# Epoch 20/30
# 489/489 - 0s - loss: 0.0838 - accuracy: 0.9796
# Epoch 21/30
# 489/489 - 0s - loss: 0.0820 - accuracy: 0.9796
# Epoch 22/30
# 489/489 - 0s - loss: 0.0736 - accuracy: 0.9775
# Epoch 23/30
# 489/489 - 0s - loss: 0.0595 - accuracy: 0.9857
# Epoch 24/30
# 489/489 - 0s - loss: 0.0605 - accuracy: 0.9836
# Epoch 25/30
# 489/489 - 0s - loss: 0.0587 - accuracy: 0.9775
# Epoch 26/30
# 489/489 - 0s - loss: 0.0531 - accuracy: 0.9796
# Epoch 27/30
# 489/489 - 0s - loss: 0.0595 - accuracy: 0.9836
# Epoch 28/30
# 489/489 - 0s - loss: 0.0494 - accuracy: 0.9857
# Epoch 29/30
# 489/489 - 0s - loss: 0.0489 - accuracy: 0.9918
# Epoch 30/30
# 489/489 - 0s - loss: 0.0461 - accuracy: 0.9898
# Train on 489 samples
# Epoch 1/30
# 489/489 - 0s - loss: 0.6623 - accuracy: 0.3885
# Epoch 2/30
# 489/489 - 0s - loss: 0.5183 - accuracy: 0.8589
# Epoch 3/30
# 489/489 - 0s - loss: 0.4083 - accuracy: 0.8855
# Epoch 4/30
# 489/489 - 0s - loss: 0.3399 - accuracy: 0.9018
# Epoch 5/30
# 489/489 - 0s - loss: 0.3078 - accuracy: 0.9202
# Epoch 6/30
# 489/489 - 0s - loss: 0.2622 - accuracy: 0.9284
# Epoch 7/30
# 489/489 - 0s - loss: 0.2356 - accuracy: 0.9284
# Epoch 8/30
# 489/489 - 0s - loss: 0.2138 - accuracy: 0.9407
# Epoch 9/30
# 489/489 - 0s - loss: 0.1944 - accuracy: 0.9489
# Epoch 10/30
# 489/489 - 0s - loss: 0.1855 - accuracy: 0.9387
# Epoch 11/30
# 489/489 - 0s - loss: 0.1581 - accuracy: 0.9489
# Epoch 12/30
# 489/489 - 0s - loss: 0.1533 - accuracy: 0.9468
# Epoch 13/30
# 489/489 - 0s - loss: 0.1420 - accuracy: 0.9632
# Epoch 14/30
# 489/489 - 0s - loss: 0.1335 - accuracy: 0.9509
# Epoch 15/30
# 489/489 - 0s - loss: 0.1264 - accuracy: 0.9632
# Epoch 16/30
# 489/489 - 0s - loss: 0.1139 - accuracy: 0.9673
# Epoch 17/30
# 489/489 - 0s - loss: 0.1044 - accuracy: 0.9652
# Epoch 18/30
# 489/489 - 0s - loss: 0.1014 - accuracy: 0.9693
# Epoch 19/30
# 489/489 - 0s - loss: 0.0907 - accuracy: 0.9775
# Epoch 20/30
# 489/489 - 0s - loss: 0.1009 - accuracy: 0.9632
# Epoch 21/30
# 489/489 - 0s - loss: 0.0950 - accuracy: 0.9693
# Epoch 22/30
# 489/489 - 0s - loss: 0.0812 - accuracy: 0.9775
# Epoch 23/30
# 489/489 - 0s - loss: 0.0956 - accuracy: 0.9673
# Epoch 24/30
# 489/489 - 0s - loss: 0.1072 - accuracy: 0.9673
# Epoch 25/30
# 489/489 - 0s - loss: 0.0858 - accuracy: 0.9755
# Epoch 26/30
# 489/489 - 0s - loss: 0.0756 - accuracy: 0.9796
# Epoch 27/30
# 489/489 - 0s - loss: 0.0711 - accuracy: 0.9816
# Epoch 28/30
# 489/489 - 0s - loss: 0.0669 - accuracy: 0.9796
# Epoch 29/30
# 489/489 - 0s - loss: 0.0645 - accuracy: 0.9755
# Epoch 30/30
# 489/489 - 0s - loss: 0.0729 - accuracy: 0.9796
# Train on 489 samples
# Epoch 1/30
# 489/489 - 0s - loss: 0.6328 - accuracy: 0.5828
# Epoch 2/30
# 489/489 - 0s - loss: 0.4915 - accuracy: 0.8569
# Epoch 3/30
# 489/489 - 0s - loss: 0.4205 - accuracy: 0.8753
# Epoch 4/30
# 489/489 - 0s - loss: 0.3652 - accuracy: 0.8916
# Epoch 5/30
# 489/489 - 0s - loss: 0.3204 - accuracy: 0.8998
# Epoch 6/30
# 489/489 - 0s - loss: 0.2978 - accuracy: 0.9018
# Epoch 7/30
# 489/489 - 0s - loss: 0.2870 - accuracy: 0.9039
# Epoch 8/30
# 489/489 - 0s - loss: 0.2487 - accuracy: 0.9202
# Epoch 9/30
# 489/489 - 0s - loss: 0.2443 - accuracy: 0.9202
# Epoch 10/30
# 489/489 - 0s - loss: 0.2051 - accuracy: 0.9366
# Epoch 11/30
# 489/489 - 0s - loss: 0.1874 - accuracy: 0.9407
# Epoch 12/30
# 489/489 - 0s - loss: 0.1742 - accuracy: 0.9448
# Epoch 13/30
# 489/489 - 0s - loss: 0.1496 - accuracy: 0.9468
# Epoch 14/30
# 489/489 - 0s - loss: 0.1330 - accuracy: 0.9530
# Epoch 15/30
# 489/489 - 0s - loss: 0.1282 - accuracy: 0.9550
# Epoch 16/30
# 489/489 - 0s - loss: 0.1185 - accuracy: 0.9632
# Epoch 17/30
# 489/489 - 0s - loss: 0.1076 - accuracy: 0.9611
# Epoch 18/30
# 489/489 - 0s - loss: 0.1077 - accuracy: 0.9632
# Epoch 19/30
# 489/489 - 0s - loss: 0.1094 - accuracy: 0.9652
# Epoch 20/30
# 489/489 - 0s - loss: 0.1207 - accuracy: 0.9611
# Epoch 21/30
# 489/489 - 0s - loss: 0.1029 - accuracy: 0.9652
# Epoch 22/30
# 489/489 - 0s - loss: 0.0939 - accuracy: 0.9693
# Epoch 23/30
# 489/489 - 0s - loss: 0.0863 - accuracy: 0.9693
# Epoch 24/30
# 489/489 - 0s - loss: 0.0788 - accuracy: 0.9755
# Epoch 25/30
# 489/489 - 0s - loss: 0.0887 - accuracy: 0.9611
# Epoch 26/30
# 489/489 - 0s - loss: 0.0752 - accuracy: 0.9755
# Epoch 27/30
# 489/489 - 0s - loss: 0.0726 - accuracy: 0.9755
# Epoch 28/30
# 489/489 - 0s - loss: 0.0701 - accuracy: 0.9734
# Epoch 29/30
# 489/489 - 0s - loss: 0.0745 - accuracy: 0.9714
# Epoch 30/30
# 489/489 - 0s - loss: 0.0679 - accuracy: 0.9693
# Train on 489 samples
# Epoch 1/30
# 489/489 - 0s - loss: 0.6212 - accuracy: 0.5910
# Epoch 2/30
# 489/489 - 0s - loss: 0.4733 - accuracy: 0.8691
# Epoch 3/30
# 489/489 - 0s - loss: 0.4049 - accuracy: 0.8875
# Epoch 4/30
# 489/489 - 0s - loss: 0.3551 - accuracy: 0.8896
# Epoch 5/30
# 489/489 - 0s - loss: 0.3265 - accuracy: 0.8978
# Epoch 6/30
# 489/489 - 0s - loss: 0.2920 - accuracy: 0.9059
# Epoch 7/30
# 489/489 - 0s - loss: 0.2655 - accuracy: 0.9121
# Epoch 8/30
# 489/489 - 0s - loss: 0.2554 - accuracy: 0.9202
# Epoch 9/30
# 489/489 - 0s - loss: 0.2223 - accuracy: 0.9305
# Epoch 10/30
# 489/489 - 0s - loss: 0.2024 - accuracy: 0.9325
# Epoch 11/30
# 489/489 - 0s - loss: 0.1899 - accuracy: 0.9305
# Epoch 12/30
# 489/489 - 0s - loss: 0.1824 - accuracy: 0.9264
# Epoch 13/30
# 489/489 - 0s - loss: 0.1570 - accuracy: 0.9407
# Epoch 14/30
# 489/489 - 0s - loss: 0.1446 - accuracy: 0.9509
# Epoch 15/30
# 489/489 - 0s - loss: 0.1317 - accuracy: 0.9550
# Epoch 16/30
# 489/489 - 0s - loss: 0.1231 - accuracy: 0.9611
# Epoch 17/30
# 489/489 - 0s - loss: 0.1113 - accuracy: 0.9591
# Epoch 18/30
# 489/489 - 0s - loss: 0.1053 - accuracy: 0.9611
# Epoch 19/30
# 489/489 - 0s - loss: 0.1018 - accuracy: 0.9693
# Epoch 20/30
# 489/489 - 0s - loss: 0.0947 - accuracy: 0.9652
# Epoch 21/30
# 489/489 - 0s - loss: 0.0881 - accuracy: 0.9693
# Epoch 22/30
# 489/489 - 0s - loss: 0.0826 - accuracy: 0.9755
# Epoch 23/30
# 489/489 - 0s - loss: 0.0827 - accuracy: 0.9775
# Epoch 24/30
# 489/489 - 0s - loss: 0.0765 - accuracy: 0.9775
# Epoch 25/30
# 489/489 - 0s - loss: 0.0795 - accuracy: 0.9714
# Epoch 26/30
# 489/489 - 0s - loss: 0.0704 - accuracy: 0.9816
# Epoch 27/30
# 489/489 - 0s - loss: 0.0746 - accuracy: 0.9755
# Epoch 28/30
# 489/489 - 0s - loss: 0.0709 - accuracy: 0.9755
# Epoch 29/30
# 489/489 - 0s - loss: 0.0732 - accuracy: 0.9755
# Epoch 30/30
# 489/489 - 0s - loss: 0.0676 - accuracy: 0.9816
# Train on 489 samples
# Epoch 1/30
# 489/489 - 0s - loss: 0.7481 - accuracy: 0.4049
# Epoch 2/30
# 489/489 - 0s - loss: 0.5683 - accuracy: 0.7280
# Epoch 3/30
# 489/489 - 0s - loss: 0.4690 - accuracy: 0.8650
# Epoch 4/30
# 489/489 - 0s - loss: 0.3868 - accuracy: 0.8855
# Epoch 5/30
# 489/489 - 0s - loss: 0.3184 - accuracy: 0.8998
# Epoch 6/30
# 489/489 - 0s - loss: 0.2752 - accuracy: 0.9202
# Epoch 7/30
# 489/489 - 0s - loss: 0.2497 - accuracy: 0.9346
# Epoch 8/30
# 489/489 - 0s - loss: 0.2192 - accuracy: 0.9366
# Epoch 9/30
# 489/489 - 0s - loss: 0.2022 - accuracy: 0.9427
# Epoch 10/30
# 489/489 - 0s - loss: 0.1912 - accuracy: 0.9366
# Epoch 11/30
# 489/489 - 0s - loss: 0.1795 - accuracy: 0.9468
# Epoch 12/30
# 489/489 - 0s - loss: 0.1808 - accuracy: 0.9407
# Epoch 13/30
# 489/489 - 0s - loss: 0.1570 - accuracy: 0.9530
# Epoch 14/30
# 489/489 - 0s - loss: 0.1408 - accuracy: 0.9611
# Epoch 15/30
# 489/489 - 0s - loss: 0.1303 - accuracy: 0.9530
# Epoch 16/30
# 489/489 - 0s - loss: 0.1281 - accuracy: 0.9611
# Epoch 17/30
# 489/489 - 0s - loss: 0.1280 - accuracy: 0.9509
# Epoch 18/30
# 489/489 - 0s - loss: 0.1390 - accuracy: 0.9571
# Epoch 19/30
# 489/489 - 0s - loss: 0.1121 - accuracy: 0.9611
# Epoch 20/30
# 489/489 - 0s - loss: 0.1105 - accuracy: 0.9632
# Epoch 21/30
# 489/489 - 0s - loss: 0.1023 - accuracy: 0.9611
# Epoch 22/30
# 489/489 - 0s - loss: 0.1000 - accuracy: 0.9591
# Epoch 23/30
# 489/489 - 0s - loss: 0.1034 - accuracy: 0.9632
# Epoch 24/30
# 489/489 - 0s - loss: 0.0901 - accuracy: 0.9673
# Epoch 25/30
# 489/489 - 0s - loss: 0.0810 - accuracy: 0.9693
# Epoch 26/30
# 489/489 - 0s - loss: 0.0829 - accuracy: 0.9673
# Epoch 27/30
# 489/489 - 0s - loss: 0.0825 - accuracy: 0.9673
# Epoch 28/30
# 489/489 - 0s - loss: 0.0752 - accuracy: 0.9652
# Epoch 29/30
# 489/489 - 0s - loss: 0.0782 - accuracy: 0.9673
# Epoch 30/30
# 489/489 - 0s - loss: 0.0766 - accuracy: 0.9734
# Train on 489 samples
# Epoch 1/30
# 489/489 - 0s - loss: 0.6426 - accuracy: 0.5930
# Epoch 2/30
# 489/489 - 0s - loss: 0.4940 - accuracy: 0.8507
# Epoch 3/30
# 489/489 - 0s - loss: 0.3883 - accuracy: 0.8998
# Epoch 4/30
# 489/489 - 0s - loss: 0.3232 - accuracy: 0.9059
# Epoch 5/30
# 489/489 - 0s - loss: 0.2735 - accuracy: 0.9182
# Epoch 6/30
# 489/489 - 0s - loss: 0.2436 - accuracy: 0.9325
# Epoch 7/30
# 489/489 - 0s - loss: 0.2166 - accuracy: 0.9366
# Epoch 8/30
# 489/489 - 0s - loss: 0.1942 - accuracy: 0.9427
# Epoch 9/30
# 489/489 - 0s - loss: 0.2172 - accuracy: 0.9264
# Epoch 10/30
# 489/489 - 0s - loss: 0.1607 - accuracy: 0.9387
# Epoch 11/30
# 489/489 - 0s - loss: 0.1443 - accuracy: 0.9571
# Epoch 12/30
# 489/489 - 0s - loss: 0.1302 - accuracy: 0.9611
# Epoch 13/30
# 489/489 - 0s - loss: 0.1254 - accuracy: 0.9571
# Epoch 14/30
# 489/489 - 0s - loss: 0.1237 - accuracy: 0.9571
# Epoch 15/30
# 489/489 - 0s - loss: 0.1221 - accuracy: 0.9571
# Epoch 16/30
# 489/489 - 0s - loss: 0.1037 - accuracy: 0.9571
# Epoch 17/30
# 489/489 - 0s - loss: 0.1043 - accuracy: 0.9632
# Epoch 18/30
# 489/489 - 0s - loss: 0.1087 - accuracy: 0.9571
# Epoch 19/30
# 489/489 - 0s - loss: 0.1019 - accuracy: 0.9652
# Epoch 20/30
# 489/489 - 0s - loss: 0.1040 - accuracy: 0.9591
# Epoch 21/30
# 489/489 - 0s - loss: 0.0784 - accuracy: 0.9755
# Epoch 22/30
# 489/489 - 0s - loss: 0.0821 - accuracy: 0.9714
# Epoch 23/30
# 489/489 - 0s - loss: 0.0838 - accuracy: 0.9693
# Epoch 24/30
# 489/489 - 0s - loss: 0.0755 - accuracy: 0.9734
# Epoch 25/30
# 489/489 - 0s - loss: 0.0845 - accuracy: 0.9652
# Epoch 26/30
# 489/489 - 0s - loss: 0.0706 - accuracy: 0.9775
# Epoch 27/30
# 489/489 - 0s - loss: 0.0728 - accuracy: 0.9673
# Epoch 28/30
# 489/489 - 0s - loss: 0.0702 - accuracy: 0.9693
# Epoch 29/30
# 489/489 - 0s - loss: 0.0634 - accuracy: 0.9734
# Epoch 30/30
# 489/489 - 0s - loss: 0.0589 - accuracy: 0.9796
# Train on 489 samples
# Epoch 1/30
# 489/489 - 0s - loss: 0.6378 - accuracy: 0.5869
# Epoch 2/30
# 489/489 - 0s - loss: 0.5079 - accuracy: 0.8425
# Epoch 3/30
# 489/489 - 0s - loss: 0.4253 - accuracy: 0.8732
# Epoch 4/30
# 489/489 - 0s - loss: 0.3728 - accuracy: 0.8773
# Epoch 5/30
# 489/489 - 0s - loss: 0.3022 - accuracy: 0.9018
# Epoch 6/30
# 489/489 - 0s - loss: 0.2673 - accuracy: 0.9121
# Epoch 7/30
# 489/489 - 0s - loss: 0.2397 - accuracy: 0.9346
# Epoch 8/30
# 489/489 - 0s - loss: 0.2203 - accuracy: 0.9305
# Epoch 9/30
# 489/489 - 0s - loss: 0.1924 - accuracy: 0.9284
# Epoch 10/30
# 489/489 - 0s - loss: 0.1790 - accuracy: 0.9366
# Epoch 11/30
# 489/489 - 0s - loss: 0.1627 - accuracy: 0.9489
# Epoch 12/30
# 489/489 - 0s - loss: 0.1473 - accuracy: 0.9611
# Epoch 13/30
# 489/489 - 0s - loss: 0.1334 - accuracy: 0.9652
# Epoch 14/30
# 489/489 - 0s - loss: 0.1166 - accuracy: 0.9673
# Epoch 15/30
# 489/489 - 0s - loss: 0.1174 - accuracy: 0.9632
# Epoch 16/30
# 489/489 - 0s - loss: 0.1000 - accuracy: 0.9734
# Epoch 17/30
# 489/489 - 0s - loss: 0.0937 - accuracy: 0.9693
# Epoch 18/30
# 489/489 - 0s - loss: 0.0880 - accuracy: 0.9775
# Epoch 19/30
# 489/489 - 0s - loss: 0.0878 - accuracy: 0.9775
# Epoch 20/30
# 489/489 - 0s - loss: 0.0782 - accuracy: 0.9693
# Epoch 21/30
# 489/489 - 0s - loss: 0.0725 - accuracy: 0.9775
# Epoch 22/30
# 489/489 - 0s - loss: 0.0659 - accuracy: 0.9775
# Epoch 23/30
# 489/489 - 0s - loss: 0.0661 - accuracy: 0.9775
# Epoch 24/30
# 489/489 - 0s - loss: 0.0801 - accuracy: 0.9714
# Epoch 25/30
# 489/489 - 0s - loss: 0.0708 - accuracy: 0.9775
# Epoch 26/30
# 489/489 - 0s - loss: 0.0701 - accuracy: 0.9755
# Epoch 27/30
# 489/489 - 0s - loss: 0.0618 - accuracy: 0.9714
# Epoch 28/30
# 489/489 - 0s - loss: 0.0598 - accuracy: 0.9775
# Epoch 29/30
# 489/489 - 0s - loss: 0.0697 - accuracy: 0.9734
# Epoch 30/30
# 489/489 - 0s - loss: 0.0631 - accuracy: 0.9857
# Train on 489 samples
# Epoch 1/30
# 489/489 - 0s - loss: 0.5576 - accuracy: 0.7710
# Epoch 2/30
# 489/489 - 0s - loss: 0.4267 - accuracy: 0.8712
# Epoch 3/30
# 489/489 - 0s - loss: 0.3527 - accuracy: 0.8957
# Epoch 4/30
# 489/489 - 0s - loss: 0.2986 - accuracy: 0.9182
# Epoch 5/30
# 489/489 - 0s - loss: 0.2727 - accuracy: 0.9223
# Epoch 6/30
# 489/489 - 0s - loss: 0.2312 - accuracy: 0.9305
# Epoch 7/30
# 489/489 - 0s - loss: 0.2077 - accuracy: 0.9427
# Epoch 8/30
# 489/489 - 0s - loss: 0.1792 - accuracy: 0.9509
# Epoch 9/30
# 489/489 - 0s - loss: 0.1637 - accuracy: 0.9468
# Epoch 10/30
# 489/489 - 0s - loss: 0.1430 - accuracy: 0.9530
# Epoch 11/30
# 489/489 - 0s - loss: 0.1437 - accuracy: 0.9530
# Epoch 12/30
# 489/489 - 0s - loss: 0.1118 - accuracy: 0.9611
# Epoch 13/30
# 489/489 - 0s - loss: 0.1102 - accuracy: 0.9611
# Epoch 14/30
# 489/489 - 0s - loss: 0.1013 - accuracy: 0.9734
# Epoch 15/30
# 489/489 - 0s - loss: 0.0901 - accuracy: 0.9693
# Epoch 16/30
# 489/489 - 0s - loss: 0.1000 - accuracy: 0.9652
# Epoch 17/30
# 489/489 - 0s - loss: 0.0859 - accuracy: 0.9673
# Epoch 18/30
# 489/489 - 0s - loss: 0.0844 - accuracy: 0.9693
# Epoch 19/30
# 489/489 - 0s - loss: 0.0809 - accuracy: 0.9693
# Epoch 20/30
# 489/489 - 0s - loss: 0.0899 - accuracy: 0.9632
# Epoch 21/30
# 489/489 - 0s - loss: 0.1138 - accuracy: 0.9611
# Epoch 22/30
# 489/489 - 0s - loss: 0.0913 - accuracy: 0.9673
# Epoch 23/30
# 489/489 - 0s - loss: 0.0759 - accuracy: 0.9775
# Epoch 24/30
# 489/489 - 0s - loss: 0.0680 - accuracy: 0.9755
# Epoch 25/30
# 489/489 - 0s - loss: 0.0664 - accuracy: 0.9755
# Epoch 26/30
# 489/489 - 0s - loss: 0.0699 - accuracy: 0.9755
# Epoch 27/30
# 489/489 - 0s - loss: 0.0632 - accuracy: 0.9816
# Epoch 28/30
# 489/489 - 0s - loss: 0.0602 - accuracy: 0.9836
# Epoch 29/30
# 489/489 - 0s - loss: 0.0669 - accuracy: 0.9714
# Epoch 30/30
# 489/489 - 0s - loss: 0.0615 - accuracy: 0.9755
# Train on 489 samples
# Epoch 1/30
# 489/489 - 0s - loss: 0.5441 - accuracy: 0.7505
# Epoch 2/30
# 489/489 - 0s - loss: 0.4252 - accuracy: 0.8691
# Epoch 3/30
# 489/489 - 0s - loss: 0.3664 - accuracy: 0.8793
# Epoch 4/30
# 489/489 - 0s - loss: 0.3209 - accuracy: 0.8978
# Epoch 5/30
# 489/489 - 0s - loss: 0.2951 - accuracy: 0.8998
# Epoch 6/30
# 489/489 - 0s - loss: 0.2524 - accuracy: 0.9202
# Epoch 7/30
# 489/489 - 0s - loss: 0.2232 - accuracy: 0.9305
# Epoch 8/30
# 489/489 - 0s - loss: 0.1983 - accuracy: 0.9387
# Epoch 9/30
# 489/489 - 0s - loss: 0.1850 - accuracy: 0.9427
# Epoch 10/30
# 489/489 - 0s - loss: 0.1571 - accuracy: 0.9468
# Epoch 11/30
# 489/489 - 0s - loss: 0.1384 - accuracy: 0.9591
# Epoch 12/30
# 489/489 - 0s - loss: 0.1234 - accuracy: 0.9591
# Epoch 13/30
# 489/489 - 0s - loss: 0.1104 - accuracy: 0.9591
# Epoch 14/30
# 489/489 - 0s - loss: 0.1065 - accuracy: 0.9632
# Epoch 15/30
# 489/489 - 0s - loss: 0.0945 - accuracy: 0.9693
# Epoch 16/30
# 489/489 - 0s - loss: 0.0853 - accuracy: 0.9734
# Epoch 17/30
# 489/489 - 0s - loss: 0.0885 - accuracy: 0.9734
# Epoch 18/30
# 489/489 - 0s - loss: 0.0811 - accuracy: 0.9734
# Epoch 19/30
# 489/489 - 0s - loss: 0.0792 - accuracy: 0.9693
# Epoch 20/30
# 489/489 - 0s - loss: 0.0785 - accuracy: 0.9714
# Epoch 21/30
# 489/489 - 0s - loss: 0.0678 - accuracy: 0.9714
# Epoch 22/30
# 489/489 - 0s - loss: 0.0670 - accuracy: 0.9775
# Epoch 23/30
# 489/489 - 0s - loss: 0.0599 - accuracy: 0.9775
# Epoch 24/30
# 489/489 - 0s - loss: 0.0597 - accuracy: 0.9775
# Epoch 25/30
# 489/489 - 0s - loss: 0.0565 - accuracy: 0.9796
# Epoch 26/30
# 489/489 - 0s - loss: 0.0569 - accuracy: 0.9796
# Epoch 27/30
# 489/489 - 0s - loss: 0.0669 - accuracy: 0.9775
# Epoch 28/30
# 489/489 - 0s - loss: 0.0484 - accuracy: 0.9877
# Epoch 29/30
# 489/489 - 0s - loss: 0.0516 - accuracy: 0.9816
# Epoch 30/30
# 489/489 - 0s - loss: 0.0525 - accuracy: 0.9775
# Train on 489 samples
# Epoch 1/30
# 489/489 - 0s - loss: 0.6719 - accuracy: 0.5930
# Epoch 2/30
# 489/489 - 0s - loss: 0.5186 - accuracy: 0.7894
# Epoch 3/30
# 489/489 - 0s - loss: 0.4230 - accuracy: 0.8650
# Epoch 4/30
# 489/489 - 0s - loss: 0.3520 - accuracy: 0.8875
# Epoch 5/30
# 489/489 - 0s - loss: 0.3153 - accuracy: 0.9039
# Epoch 6/30
# 489/489 - 0s - loss: 0.2670 - accuracy: 0.9223
# Epoch 7/30
# 489/489 - 0s - loss: 0.2368 - accuracy: 0.9305
# Epoch 8/30
# 489/489 - 0s - loss: 0.2218 - accuracy: 0.9346
# Epoch 9/30
# 489/489 - 0s - loss: 0.1942 - accuracy: 0.9346
# Epoch 10/30
# 489/489 - 0s - loss: 0.1742 - accuracy: 0.9407
# Epoch 11/30
# 489/489 - 0s - loss: 0.1508 - accuracy: 0.9509
# Epoch 12/30
# 489/489 - 0s - loss: 0.1362 - accuracy: 0.9591
# Epoch 13/30
# 489/489 - 0s - loss: 0.1228 - accuracy: 0.9571
# Epoch 14/30
# 489/489 - 0s - loss: 0.1126 - accuracy: 0.9652
# Epoch 15/30
# 489/489 - 0s - loss: 0.1093 - accuracy: 0.9652
# Epoch 16/30
# 489/489 - 0s - loss: 0.1041 - accuracy: 0.9611
# Epoch 17/30
# 489/489 - 0s - loss: 0.0879 - accuracy: 0.9734
# Epoch 18/30
# 489/489 - 0s - loss: 0.0788 - accuracy: 0.9714
# Epoch 19/30
# 489/489 - 0s - loss: 0.0749 - accuracy: 0.9775
# Epoch 20/30
# 489/489 - 0s - loss: 0.0685 - accuracy: 0.9734
# Epoch 21/30
# 489/489 - 0s - loss: 0.0660 - accuracy: 0.9775
# Epoch 22/30
# 489/489 - 0s - loss: 0.0636 - accuracy: 0.9836
# Epoch 23/30
# 489/489 - 0s - loss: 0.0584 - accuracy: 0.9877
# Epoch 24/30
# 489/489 - 0s - loss: 0.0533 - accuracy: 0.9857
# Epoch 25/30
# 489/489 - 0s - loss: 0.0497 - accuracy: 0.9898
# Epoch 26/30
# 489/489 - 0s - loss: 0.0477 - accuracy: 0.9898
# Epoch 27/30
# 489/489 - 0s - loss: 0.0533 - accuracy: 0.9775
# Epoch 28/30
# 489/489 - 0s - loss: 0.0435 - accuracy: 0.9877
# Epoch 29/30
# 489/489 - 0s - loss: 0.0413 - accuracy: 0.9939
# Epoch 30/30
# 489/489 - 0s - loss: 0.0643 - accuracy: 0.9755
# Mean accuracy based on 10 random partitions of the total dataset =  0.94619054

# %%
accuracy = np.mean(acc)
print('Mean accuracy based on 10 random partitions of the total dataset = ', accuracy)
# Out:
# Mean accuracy based on 10 random partitions of the total dataset =  0.94619054
